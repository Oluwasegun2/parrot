# %%
# Importing needed dependencies
from pyspark.sql import *
import pyspark.sql.functions as F
from pyspark.sql.functions import to_json, col
import json as j

from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import from_json, col, when
from pyspark.sql.functions import regexp_replace, col
from pyspark.sql.functions import col, to_timestamp, to_date

# %%
# Listing the files in the bronze folder
dbutils.fs.ls('mnt/bronze/')
# Out:
# [FileInfo(path='dbfs:/mnt/bronze/business.json', name='business.json', size=3498714, modificationTime=1749577662000),
#  FileInfo(path='dbfs:/mnt/bronze/categories.json', name='categories.json', size=11560, modificationTime=1749577711000),
#  FileInfo(path='dbfs:/mnt/bronze/review.json', name='review.json', size=338843, modificationTime=1749577787000),
#  FileInfo(path='dbfs:/mnt/bronze/sub_categories.json', name='sub_categories.json', size=84165, modificationTime=1749577753000),
#  FileInfo(path='dbfs:/mnt/bronze/user.json', name='user.json', size=878114, modificationTime=1749577819000)]

# %% [markdown]
# # Transforming the Json files into Tables

# %%
# Load the business JSON file
df1 = spark.read.json("dbfs:/mnt/bronze/business.json")
df1.printSchema()
# Out:
# root
#  |-- __v: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- addressVerified: boolean (nullable = true)
#  |-- bookmarks: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- branchesInOtherLocations: boolean (nullable = true)
#  |-- businessCategory: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- businessDescription: string (nullable = true)
#  |-- businessEmail: string (nullable = true)
#  |-- businessEmailVerified: boolean (nullable = true)
#  |-- businessMedia: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- businessName: string (nullable = true)
#  |-- businessPhoneNumber: string (nullable = true)
#  |-- businessPhoneNumberVerified: boolean (nullable = true)
#  |-- businessProductAndService: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- businessSubCategory: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- city: string (nullable = true)
#  |-- claimed: boolean (nullable = true)
#  |-- contactPerson: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- createdAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- deviceTokens: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- documentVerified: boolean (nullable = true)
#  |-- emailInvitation: string (nullable = true)
#  |-- googleLocationData: struct (nullable = true)
#  |    |-- address_components: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- _id: string (nullable = true)
#  |    |    |    |-- long_name: string (nullable = true)
#  |    |    |    |-- short_name: string (nullable = true)
#  |    |    |    |-- types: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- adr_address: string (nullable = true)
#  |    |-- formatted_address: string (nullable = true)
#  |    |-- geometry: struct (nullable = true)
#  |    |    |-- location: struct (nullable = true)
#  |    |    |    |-- lat: struct (nullable = true)
#  |    |    |    |    |-- $numberDouble: string (nullable = true)
#  |    |    |    |-- lng: struct (nullable = true)
#  |    |    |    |    |-- $numberDouble: string (nullable = true)
#  |    |-- html_attributions: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- icon: string (nullable = true)
#  |    |-- icon_background_color: string (nullable = true)
#  |    |-- icon_mask_base_uri: string (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- photos: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- _id: string (nullable = true)
#  |    |    |    |-- height: struct (nullable = true)
#  |    |    |    |    |-- $numberInt: string (nullable = true)
#  |    |    |    |-- width: struct (nullable = true)
#  |    |    |    |    |-- $numberInt: string (nullable = true)
#  |    |-- place_id: string (nullable = true)
#  |    |-- position: struct (nullable = true)
#  |    |    |-- lat: struct (nullable = true)
#  |    |    |    |-- $numberDouble: string (nullable = true)
#  |    |    |-- lng: struct (nullable = true)
#  |    |    |    |-- $numberDouble: string (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- types: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- url: string (nullable = true)
#  |    |-- utc_offset: string (nullable = true)
#  |    |-- utc_offset_minutes: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- vicinity: string (nullable = true)
#  |-- invitationRequest: struct (nullable = true)
#  |    |-- byUser: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |-- isExpired: boolean (nullable = true)
#  |-- metricScore: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- officialName: string (nullable = true)
#  |-- parrotScore: struct (nullable = true)
#  |    |-- $numberDouble: string (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- password: string (nullable = true)
#  |-- phoneNumberInvitation: string (nullable = true)
#  |-- phoneNumbersOfContactPerson: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- reviews: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- state: string (nullable = true)
#  |-- subscribers: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- theme: string (nullable = true)
#  |-- titleOfContactPerson: string (nullable = true)
#  |-- updatedAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- urlShortener: struct (nullable = true)
#  |    |-- originalUrl: string (nullable = true)
#  |    |-- shortenedUrl: string (nullable = true)
#  |    |-- urlShortenerMapper: string (nullable = true)
#  |-- username: string (nullable = true)

# %%
oid_schema = StructType([
    StructField("$oid", StringType(), True)
])

# %%
df_business = df1.withColumn('business_category', F.explode('businessCategory')).\
                withColumn('business_subcategory', F.explode('businessSubCategory')).\
                withColumn('business_id', F.col('_id.$oid')).\
                withColumn(
                        "business_categories_id",
                        regexp_replace(col("business_category"), r'^\{"\$oid":"|"\}$', '')
                    ).\
                withColumn(
                        "business_subcategories_id",
                        regexp_replace(col("business_subcategory"), r'^\{"\$oid":"|"\}$', '')
                    ).\
                select('business_id','address','business_categories_id','business_subcategories_id','businessName',
                'businessPhoneNumber','city','state','claimed','contactPerson',
                'businessEmail')

display(df_business)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
td>Angel Florah</td><td>2348149314437</td><td>Akure </td><td>Ondo </td><td>false</td><td></td><td>angelflorah01@gmail.com</td></tr><tr><td>65ead406ea78b88f1875c1f0</td><td></td><td>65e05b00d460100f731eafb9</td><td>65e05b02d460100f731eafc8</td><td>Angel Florah</td><td>2348149314437</td><td>Akure </td><td>Ondo </td><td>false</td><td></td><td>angelflorah01@gmail.com</td></tr><tr><td>65ead414ea78b88f1875c20f</td><td></td><td>65e05b45d460100f731eb168</td><td>65e05b45d460100f731eb16a</td><td>First Molac Hotel</td><td>2347066225412</td><td>Akure</td><td>Ondo</td><td>false</td><td>Oluwasegun</td><td>oluwasegunjuwon1234@gmail.com</td></tr><tr><td>65ead414ea78b88f1875c20f</td><td></td><td>65e05b45d460100f731eb168</td><td>65e05b46d460100f731eb16e</td><td>First Molac Hotel</td><td>2347066225412</td><td>Akure</td><td>Ondo</td><td>false</td><td>Oluwasegun</td><td>oluwasegunjuwon1234@gmail.com</td></tr><tr><td>65ead476ea78b88f1875c2ae</td><td></td><td>65e05b13d460100f731eb038</td><td>65e05b13d460100f731eb03e</td><td>Becca's Cake And Surprise </td><td>2348085039005</td><td>Akure</td><td>Ondo State </td><td>false</td><td>Ifabumuyi Rebecca </td><td>rebeccaifabumuyi@gmail.com</td></tr><tr><td>65ead4beea78b88f1875c30c</td><td>7743+VRX, Sunshine Garden'S Rd, Oba Ile 340106, Ondo, Nigeria</td><td>65e05b10d460100f731eb028</td><td>65e05b11d460100f731eb02c</td><td>Ramat Barbing Saloon </ ...

# %%
### to save the business file in a paruet file

df_business.write.mode('overwrite').parquet("dbfs:/mnt/silver/business")

# %%
# Load the category JSON file
df2 = spark.read.json("dbfs:/mnt/bronze/categories.json")
df2.printSchema()
# Out:
# root
#  |-- __v: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- createdAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- imageUrl: string (nullable = true)
#  |-- metrics: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- status: string (nullable = true)

# %%
df_categories = df2.withColumn('metrics', F.explode('metrics')).\
                withColumn('categories_id', F.col('_id.$oid')).\
                 select('categories_id','metrics','name','slug','status')
display(df_categories)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>categories_id</th><th>metrics</th><th>name</th><th>slug</th><th>status</th></tr></thead><tbody><tr><td>65e05afed460100f731eaf9e</td><td>Food Quality</td><td>Restaurants And Bars</td><td>restaurants-and-bars</td><td>Active</td></tr><tr><td>65e05afed460100f731eaf9e</td><td>Customer Service</td><td>Restaurants And Bars</td><td>restaurants-and-bars</td><td>Active</td></tr><tr><td>65e05afed460100f731eaf9e</td><td>Wait Time</td><td>Restaurants And Bars</td><td>restaurants-and-bars</td><td>Active</td></tr><tr><td>65e05afed460100f731eaf9e</td><
>Active</td></tr><tr><td>65e05b0ad460100f731eb002</td><td>Wait Time</td><td>Pet & Veterinary</td><td>pet-and-veterinary</td><td>Active</td></tr><tr><td>65e05b0ad460100f731eb002</td><td>Professionalism</td><td>Pet & Veterinary</td><td>pet-and-veterinary</td><td>Active</td></tr><tr><td>65e05b0cd460100f731eb010</td><td>Customer Service</td><td>Entertainment</td>< ...

# %%
### to save the categories file in a parquet file

df_categories.write.mode('overwrite').parquet("dbfs:/mnt/silver/categories")

# %%
# Load the sub_category JSON file
df3 = spark.read.json("dbfs:/mnt/bronze/sub_categories.json")
df3.printSchema()
# Out:
# root
#  |-- __v: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- categoryIds: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- $oid: string (nullable = true)
#  |-- createdAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- updatedAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)

# %%
df_subcategories = df3.withColumn('categories_id', F.explode('categoryIds')).\
                   withColumn('subcategories_id', F.col('_id.$oid')).\
                   withColumn('categories_id', F.col('categories_id.$oid')).\
                 select('subcategories_id','categories_id','name','slug','status','description')
display(df_subcategories)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>subcategories_id</th><th>categories_id</th><th>name</th><th>slug</th><th>status</th><th>description</th></tr></thead><tbody><tr><td>65e05afed460100f731eafa2</td><td>65e05afed460100f731eaf9e</td><td>African and Pacific Cuisine</td><td>african-and-pacific-cuisine</td><td>Active</td><td>Traditional African and Pacific cuisine.</td></tr><tr><td>65e05afed460100f731eafa4</td><td>65e05afed460100f731eaf9e</td><td>Bars and Cafes</td><td>bars-and-cafes</td><td>Active</td><td>Bars and cafes for food and drinks.</td></tr><tr><td>65e05afed460100f731eafa6</td><td>65e05afed460100f731eaf9e</td><td>Nigerian Cuisine</td><td>nigerian-cuisine</td><td>Active</td><td>Service establishments offering fast meals.</td></tr><tr><td>65e05affd460100f731eafa9</td><td>65e05afed460100f731eaf9e</td><td>European Cuisine</td><td>european-cuisine</td><td>Active</td><td>European cuisine for food and drinks.</td></tr><tr><td>65e05affd460100f731eafab</td><td>65e05afed460100f731eaf9e</td><td>General Restaurants</td><td>general-restaurants</td><td>Active</td><td>General restaurants for food and drinks.</td></tr><tr><td>65e05affd460100f731eafae</td><td>65e05afed460100f731eaf9e</td><td>Launch</td><td>launch</td><td>Active</td><td>Launch for food and drinks.</td></tr><tr><td>65e05affd460100f731eafb1</td><td>65e05afed460100f731eaf9e</td><td>Dinner</td><td>dinner</td><td>Active</td><td>Dinner for food and drinks.</td></tr><tr><td>65e05b00d460100f731eafb4</td><td>65e05afed460100f731eaf9e</td><td>Breakfast</td><td>breakfast</td><td>Active</td><td>Breakfast for food and drinks.</td></tr><tr><td>65e05b00d460100f731eafb7</td><td>65e05afed460100f731eaf9e</td><td>Snacks</td><td>snacks</td><td>Active</td><td>Snacks for food and drinks.</td></tr><tr><td>65e05b00d460100f731eafbc</td><td>65e05b00d460100f731eafb9</td><td>Accessories</td><td>accessories</td><td>Active</td><td>Complementary items to enhance fashion outfits.</td></tr><tr><td>65e05b01d460100f731eafbf</td><td>65e05b00d460100f731eafb9</td><td>Clothing and Underwear</td><td>clothing-and-underwear</td><td>Active</td><td>Stores offering a variety of clothing and underwear.</td></tr><tr><td>65e05b01d460100f731eafc2</td><td>65e05b00d460100f731eafb9</td><td>Clothing Rental and Repair</td><td>clothing-rental-and-repair</td><td>Active</td><td>Services for renting and repairing clothing.</td></tr><tr><td>65e05b01d460100f731eafc4</td><td>65e05b00d460100f731eafb9</td><td>Costume and Wedding</td><td>costume-and-wedding</td><td>Active</td><td>Services for costume and wedding.</td></tr><tr><td>65e05b01d460100f731eafc6</td><td>65e05b00d460100f731eafb9</td><td>Jewelry and Watches</td><td>jewelry-and-watches</td><td>Active</td><td>Stores offering a variety of jewelry and watches.</td></tr><tr><td>65e05b02d460100f731eafc8</td><td>65e05b00d460100f731eafb9</td><td>Men Wears</td><td>men-wears</td><td>Active</td><td>Stores offering men wears.</td></tr><tr><td>65e05b02d460100f731eafca</td><td>65e05b00d460100f731eafb9</td><td>Children wears</td><td>children-wears</td><td>Active</td><td>Stores offering children wears.</td></tr><tr><td>65e05b02d460100f731eafcd</td><td>65e05b00d460100f731eafb9</td><td>Traditional Wears</td><td>traditional-wears</td><td>Active</td><td>Stores offering traditional wears.</td></tr><tr><td>65e05b02d460100f731eafd0</td><td>65e05b00d460100f731eafb9</td><td>Women Wears</td><td>women-wears</td><td>Active</td><td>Stores offering Women wears</td></tr><tr><td>65e05b03d460100f731eafd2</td><td>65e05b00d460100f731eafb9</td><td>Sportswear</td><td>sportswear</td><td>Active</td><td>Stores offering sportswear.</td></tr><tr><td>65e05b04d460100f731eafd6</td><td>65e05b03d460100f731eafd4</td><td>Cleaning Services Providers</td><td>cleaning-services-providers</td><td>Active</td><td>Residential and commercial cleaning assistance.</td></tr><tr><td>65e05b04d460100f731eafd8</td><td>65e05b03d460100f731eafd4</td><td>Craftsmen</t ...

# %%
### to save the sub_categories file in a parquet file

df_subcategories.write.mode('overwrite').parquet("dbfs:/mnt/silver/subcategories")

# %%
# Load the users JSON file
df4 = spark.read.json("dbfs:/mnt/bronze/user.json")
df4.printSchema()
# Out:
# root
#  |-- __v: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- bookmarks: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- $oid: string (nullable = true)
#  |-- bvn: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- createdAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- dateOfBirth: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- deviceTokens: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- _id: struct (nullable = true)
#  |    |    |    |-- $oid: string (nullable = true)
#  |    |    |-- platform: string (nullable = true)
#  |    |    |-- token: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- emailVerified: boolean (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- image: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- interestCategories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- isCreator: boolean (nullable = true)
#  |-- isInterestAdded: boolean (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- nin: string (nullable = true)
#  |-- password: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- phoneVerified: boolean (nullable = true)
#  |-- photoVerified: boolean (nullable = true)
#  |-- referalCount: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- reviews: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- $oid: string (nullable = true)
#  |-- socialId: string (nullable = true)
#  |-- socialSignUp: boolean (nullable = true)
#  |-- state: string (nullable = true)
#  |-- updatedAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- username: string (nullable = true)
#  |-- verificationStatus: boolean (nullable = true)

# %%
df_users = df4.withColumn('users_id', F.col('_id.$oid')).\
            select('users_id','firstName','lastName','gender','state','username','city','email','verificationStatus')
display(df_users)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>users_id</th><th>firstName</th><th>lastName</th><th>gender</th><th>state</th><th>username</th><th>city</th><th>email</th><th>verificationStatus</th></tr></thead><tbody><tr><td>66e9c426e970e655731d0be8</td><td>Adekola</td><td>Owoade</td><td>Male</td><td>Ondo</td><td>Petra</td><td>Akure</td><td>owoadekola95@gmail.com</td><td>true</td></tr><tr><td>66ea9090e970e655731d0cef</td><td>Seyi</td><td>Oke</td><td>null</td><td></td><td>Ragna</td><td></td><td>appmeseyi6@gmail.com</td><td>false</td></tr><tr><td>66eac1270389b10cf8647f95</td><td>Daniel</td><td>Oyekunle</td><td>null</td><td></td><td>dcares</td><td></td><td>dannicares@gmail.com</td><td>false</td></tr><tr><td>66eaedba0389b10cf8648040</td><td>Dolapo</td><td>Adedoyin</td><td>Female</td><td>Ondo</td><td>Dola</td><td>Akure</td><td>dholliepearl5@gmail.com</td><td>true</td></tr><tr><td>66eaef080389b10cf8648081</td><td>Reese</td><td>Uvoh</td><td>Female</td><td>Ondo</td><td>Marigold</td><td>Akure </td><td>uvohprecious06@gmail.com</td><td>true</td></tr><tr><td>66eaef1b0389b10cf8648095</td><td>Boluwatife</td><td>Oludupin</td><td>Male</td><td>Ondo</td><td>Bovico</
# %%
### to save the users file in a parquet file

df_users.write.mode('overwrite').parquet("dbfs:/mnt/silver/users")

# %%
# Load the reviews JSON file
df5 = spark.read.json("dbfs:/mnt/bronze/review.json")
df5.printSchema()
# Out:
# root
#  |-- __v: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- _id: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- bookmarkedBy: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- $oid: string (nullable = true)
#  |-- business: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- businessCategory: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)
#  |-- createdAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- dateOfExperience: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- downVoters: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- $oid: string (nullable = true)
#  |-- downVotes: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- experienceSummary: string (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- mimeType: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- imagesForFlagging: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- isEdited: boolean (nullable = true)
#  |-- isFlagged: boolean (nullable = true)
#  |-- isPublished: boolean (nullable = true)
#  |-- rating: struct (nullable = true)
#  |    |-- Accessibility: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Appointment Flexibility: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Buying Experience: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Classes & Programs: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Cleanliness & Ambience: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Customer Service: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Entertainment: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Equipment Quality: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Food & Dining: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Food Quality: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Food and Beverages: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Learning Experience: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Networking & Interaction: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Organization: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Packaging: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Product Quality: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Professionalism: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Quality of Care: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Quality of Curriculum: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Quality of Instructors: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Quality of Service: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Room Quality: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Safety & Security: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Security: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Service Quality: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Session Quality: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Timeliness: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Value for Money: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |    |-- Wait Time: struct (nullable = true)
#  |    |    |-- $numberInt: string (nullable = true)
#  |-- replies: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- $oid: string (nullable = true)
#  |-- upVoters: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- $oid: string (nullable = true)
#  |-- upVotes: struct (nullable = true)
#  |    |-- $numberInt: string (nullable = true)
#  |-- updatedAt: struct (nullable = true)
#  |    |-- $date: struct (nullable = true)
#  |    |    |-- $numberLong: string (nullable = true)
#  |-- user: struct (nullable = true)
#  |    |-- $oid: string (nullable = true)

# %%
# to define the date schema
numberLong_schema = StructType([
    StructField("$numberLong", StringType(), True)
])

# %%
df_reviews = df5.withColumn('reviews_id', F.col('_id.$oid')).\
                withColumn('business_id', F.col('business.$oid')).\
                withColumn('user', F.col('user.$oid')).\
                withColumn("business_category_id", F.col("businessCategory.$oid")).\
                withColumn(
                                "dateOfExperience",
                                to_timestamp((col("dateOfExperience.$date.$numberLong").cast("long") / 1000))
                            ).\
                withColumn(
                                "date_of_experience",
                                to_date("dateOfExperience")
                            ).\
                    withColumn('Accessibility', col('rating.Accessibility.$numberInt').cast("int")).\
                    withColumn('Appointment Flexibility', col('rating.Appointment Flexibility.$numberInt').cast("int")).\
                    withColumn('Buying Experience', col('rating.Buying Experience.$numberInt').cast("int")).\
                    withColumn('Classes and Programs', col('rating.Classes & Programs.$numberInt').cast("int")).\
                    withColumn('Cleanliness and Ambience', col('rating.Cleanliness & Ambience.$numberInt').cast("int")).\
                    withColumn('Customer Service', col('rating.Customer Service.$numberInt').cast("int")).\
                    withColumn('Equipment Quality', col('rating.Equipment Quality.$numberInt').cast("int")).\
                    withColumn('Food and Dining', col('rating.Food & Dining.$numberInt').cast("int")).\
                    withColumn('Food Quality', col('rating.Food Quality.$numberInt').cast("int")).\
                    withColumn('Learning Experience', col('rating.Learning Experience.$numberInt').cast("int")).\
                    withColumn('Networking and Interaction', col('rating.Networking & Interaction.$numberInt').cast("int")).\
                    withColumn('Organization', col('rating.Organization.$numberInt').cast("int")).\
                    withColumn('Product Quality', col('rating.Product Quality.$numberInt').cast("int")).\
                    withColumn('Professionalism', col('rating.Professionalism.$numberInt').cast("int")).\
                    withColumn('Quality of Care', col('rating.Quality of Care.$numberInt').cast("int")).\
                    withColumn('Quality of Curriculum', col('rating.Quality of Curriculum.$numberInt').cast("int")).\
                    withColumn('Quality of Instructors', col('rating.Quality of Instructors.$numberInt').cast("int")).\
                    withColumn('Quality of Service', col('rating.Quality of Service.$numberInt').cast("int")).\
                    withColumn('Room Quality', col('rating.Room Quality.$numberInt').cast("int")).\
                    withColumn('Safety and Security', col('rating.Safety & Security.$numberInt').cast("int")).\
                    withColumn('Security', col('rating.Security.$numberInt').cast("int")).\
                    withColumn('Service Quality', col('rating.Service Quality.$numberInt').cast("int")).\
                    withColumn('Session Quality', col('rating.Session Quality.$numberInt').cast("int")).\
                    withColumn('Timeliness', col('rating.Timeliness.$numberInt').cast("int")).\
                    withColumn('Wait Time', col('rating.Wait Time.$numberInt').cast("int")).\
                        select("reviews_id","business_id","business_category_id","date_of_experience",
                        F.col("experienceSummary").alias("reviews"),
                        F.col("user").alias("user_id"),
                        F.col("Accessibility"),
                        F.col("Appointment Flexibility"),
                        F.col("Buying Experience"),
                        F.col("Classes and Programs"),
                        F.col("Cleanliness and Ambience"),
                        F.col("Customer Service"),
                        F.col("Equipment Quality"),
                        F.col("Food and Dining"),
                        F.col("Food Quality"),
                        F.col("Learning Experience"),
                        F.col("Networking and Interaction"),
                        F.col("Organization"),
                        F.col("Product Quality"),
                        F.col("Professionalism"),
                        F.col("Quality of Care"),
                        F.col("Quality of Curriculum"),
                        F.col("Quality of Instructors"),
                        F.col("Quality of Service"),
                        F.col("Room Quality"),
                        F.col("Safety and Security"),
                        F.col("Security"),
                        F.col("Service Quality"),
                        F.col("Session Quality"),
                        F.col("Timeliness"),
                        F.col("Wait Time")                    )




display(df_reviews)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>reviews_id</th><th>business_id</th><th>business_category_id</th><th>date_of_experience</th><th>reviews</th><th>user_id</th><th>Accessibility</th><th>Appointment Flexibility</th><th>Buying Experience</th><th>Classes and Programs</th><th>Cleanliness and Ambience</th><th>Customer Service</th><th>Equipment Quality</th><th>Food and Dining</th><th>Food Quality</th><th>Learning Experience</th><th>Networking and Interaction</th><th>Organization</th><th>Product Quality</th><th>Professionalism</th><th>Quality of Care</th><th>Quality of Curriculum</th><th>Quality of Instructors</th><th>Quality of Service</th><th>Room Quality</th><th>Safety and Security</th><th>Security
td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>5</td></tr><tr><td>66efb33915b0efb41b861c9b</td><td>65f306614e5b5b9c84a86846</td><td>65e05afed460100f731eaf9e</td><td>2024-09-22</td><td>Well, whenever I need to eat a food that tastes like homemade food, Ovie is my go to person though her food is a bit expensive but it's understandable considering the prices of things in the country. However I think she needs to get a proper space as eating in an open place isn't really cool.</td><td>66ec4c0915b0efb41b861790</td><td>null</td><td>null</td><td>null</td><td>null</td><td>3</td><td>2</td><td>null</td><td>null</td><td>4</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2</td></tr><tr><td>66efb49e15b0efb41b861d29</td><td>66e187dd1d1ca70126cc0b56</td><td>65e05b25d460100f731eb0b0</td><td>2024-09-22</td><td>Zacrac Learning offers a great learning experience for newbies to tech, they aren't just concerned about your money they are very much concerned about making impacts. I simply believe they're the best in Akure. So if you are in Akure check them out!!!!!</td><td>66ec4c0915b0efb41b861790</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>4</td><td>null</td><td>null</td><td>null</td><td>3</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>3</td><td>3</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>66f3e45571c0fe89748d3463</td><td>65f2ff144e5b5b9c84a86240</td><td>65e05afed4601 ...

# %%
### to save the reviews file in a parquet file

df_reviews.write.mode('overwrite').parquet("dbfs:/mnt/silver/reviews")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7283909769339479>, line 1
# ----> 1 df_reviews = df5.withColumn('_id', F.col('_id.$oid')).\
#       2                 withColumn('business_id', F.col('business.$oid')).\
#       3                 withColumn('user', F.col('user.$oid')).\
#       4                 withColumn("businessCategory", F.col("businessCategory.$oid")).\
#       5                 withColumn(
#       6                                 "dateOfExperience",
#       7                                 to_timestamp((col("dateOfExperience.$date.$numberLong").cast("long") / 1000))
#       8                             ).\
#       9                 withColumn(
#      10                                 "dateOfExperience",
#      11                                 to_date("dateOfExperience")
#      12                             ).\
#      13                     withColumn('Accessibility', col('rating.Accessibility.$numberInt').cast("int")).\
#      14                     withColumn('Appointment Flexibility', col('rating.Appointment Flexibility.$numberInt').cast("int")).\
#      15                     withColumn('Buying Experience', col('rating.Buying Experience.$numberInt').cast("int")).\
#      16                     withColumn('Classes & Programs', col('rating.Classes & Programs.$numberInt').cast("int")).\
#      17                     withColumn('Cleanliness & Ambience', col('rating.Cleanliness & Ambience.$numberInt').cast("int")).\
#      18                     withColumn('Customer Service', col('rating.Customer Service.$numberInt').cast("int")).\
#      19                     withColumn('Equipment Quality', col('rating.Equipment Quality.$numberInt').cast("int")).\
#      20                     withColumn('Food & Dining', col('rating.Food & Dining.$numberInt').cast("int")).\
#      21                     withColumn('Food Quality', col('rating.Food Quality.$numberInt').cast("int")).\
#      22                     withColumn('Learning Experience', col('rating.Learning Experience.$numberInt').cast("int")).\
#      23                     withColumn('Networking & Interaction', col('rating.Networking & Interaction.$numberInt').cast("int")).\
#      24                     withColumn('Organization', col('rating.Organization.$numberInt').cast("int")).\
#      25                     withColumn('Product Quality', col('rating.Product Quality.$numberInt').cast("int")).\
#      26                     withColumn('Professionalism', col('rating.Professionalism.$numberInt').cast("int")).\
#      27                     withColumn('Quality of Care', col('rating.Quality of Care.$numberInt').cast("int")).\
#      28                     withColumn('Quality of Curriculum', col('rating.Quality of Curriculum.$numberInt').cast("int")).\
#      29                     withColumn('Quality of Instructors', col('rating.Quality of Instructors.$numberInt').cast("int")).\
#      30                     withColumn('Quality of Service', col('rating.Quality of Service.$numberInt').cast("int")).\
#      31                     withColumn('Room Quality', col('rating.Room Quality.$numberInt').cast("int")).\
#      32                     withColumn('Safety & Security', col('rating.Safety & Security.$numberInt').cast("int")).\
#      33                     withColumn('Security', col('rating.Security.$numberInt').cast("int")).\
#      34                     withColumn('Service Quality', col('rating.Service Quality.$numberInt').cast("int")).\
#      35                     withColumn('Session Quality', col('rating.Session Quality.$numberInt').cast("int")).\
#      36                     withColumn('Timeliness', col('rating.Timeliness.$numberInt').cast("int")).\
#      37                     withColumn('Wait Time', col('rating.Wait Time.$numberInt').cast("int")).\
#      38                         select("_id","business_id","businessCategory","dateOfExperience","experienceSummary",
#      39                         F.col("user").alias("user_id"),
#      40                         F.col("Accessibility"),
#      41                         F.col("Appointment Flexibility"),
#      42                         F.col("Buying Experience"),
#      43                         F.col("Classes and Programs"),
#      44                         F.col("Cleanliness and Ambience"),
#      45                         F.col("Customer Service"),
#      46                         F.col("Equipment Quality"),
#      47                         F.col("Food and Dining"),
#      48                         F.col("Food Quality"),
#      49                         F.col("Learning Experience"),
#      50                         F.col("Networking and Interaction"),
#      51                         F.col("Organization"),
#      52                         F.col("Product Quality"),
#      53                         F.col("Professionalism"),
#      54                         F.col("Quality of Care"),
#      55                         F.col("Quality of Curriculum"),
#      56                         F.col("Quality of Instructors"),
#      57                         F.col("Quality of Service"),
#      58                         F.col("Room Quality"),
#      59                         F.col("Safety and Security"),
#      60                         F.col("Security"),
#      61                         F.col("Service Quality"),
#      62                         F.col("Session Quality"),
#      63                         F.col("Timeliness"),
#      64                         F.col("Wait Time")                    )
#      69 display(df_reviews)
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:47, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      45 start = time.perf_counter()
#      46 try:
# ---> 47     res = func(*args, **kwargs)
#      48     logger.log_success(
#      49         module_name, class_name, function_name, time.perf_counter() - start, signature
#      50     )
#      51     return res
#
# File /databricks/spark/python/pyspark/sql/dataframe.py:3853, in DataFrame.select(self, *cols)
#    3808 def select(self, *cols: "ColumnOrName") -> "DataFrame":  # type: ignore[misc]
#    3809     """Projects a set of expressions and returns a new :class:`DataFrame`.
#    3810
#    3811     .. versionadded:: 1.3.0
#    (...)
#    3851     +-----+---+
#    3852     """
# -> 3853     jdf = self._jdf.select(self._jcols(*cols))
#    3854     return DataFrame(jdf, self.sparkSession)
#
# File /databricks/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1355, in JavaMember.__call__(self, *args)
#    1349 command = proto.CALL_COMMAND_NAME +\
#    1350     self.command_header +\
#    1351     args_command +\
#    1352     proto.END_COMMAND_PART
#    1354 answer = self.gateway_client.send_command(command)
# -> 1355 return_value = get_return_value(
#    1356     answer, self.gateway_client, self.target_id, self.name)
#    1358 for temp_arg in temp_args:
#    1359     if hasattr(temp_arg, "_detach"):
#
# File /databricks/spark/python/pyspark/errors/exceptions/captured.py:261, in capture_sql_exception.<locals>.deco(*a, **kw)
#     257 converted = convert_exception(e.java_exception)
#     258 if not isinstance(converted, UnknownException):
#     259     # Hide where the exception came from that shows a non-Pythonic
#     260     # JVM exception message.
# --> 261     raise converted from None
#     262 else:
#     263     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `Classes and Programs` cannot be resolved. Did you mean one of the following? [`Classes & Programs`, `Quality of Care`, `Safety & Security`, `Session Quality`, `businessCategory`]. SQLSTATE: 42703;
# 'Project [_id#9545, business_id#9569, businessCategory#9617, dateOfExperience#9665, experienceSummary#9512, user#9593 AS user_id#10613, Accessibility#9688, Appointment Flexibility#9713, Buying Experience#9739, 'Classes and Programs, 'Cleanliness and Ambience, Customer Service#9823, Equipment Quality#9853, 'Food and Dining, Food Quality#9916, Learning Experience#9949, 'Networking and Interaction, Organization#10018, Product Quality#10054, Professionalism#10091, Quality of Care#10129, Quality of Curriculum#10168, Quality of Instructors#10208, Quality of Service#10249, ... 7 more fields]
# +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, ... 23 more fields]
#    +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, ... 22 more fields]
#       +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, ... 21 more fields]
#          +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, ... 20 more fields]
#                                                       +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, ... 5 more fields]
#                                                          +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, ... 4 more fields]
#                                                             +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, ... 3 more fields]
#                                                                +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, ... 2 more fields]
#                                                                   +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, Appointment Flexibility#9713, cast(rating#9518.Buying Experience.$numberInt as int) AS Buying Experience#9739]
#                                                                      +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, Accessibility#9688, cast(rating#9518.Appointment Flexibility.$numberInt as int) AS Appointment Flexibility#9713]
#                                                                         +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569, cast(rating#9518.Accessibility.$numberInt as int) AS Accessibility#9688]
#                                                                            +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, to_date(dateOfExperience#9641, None, Some(Etc/UTC), false) AS dateOfExperience#9665, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569]
#                                                                               +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9617, createdAt#9508, to_timestamp((cast(cast(dateOfExperience#9509.$date.$numberLong as bigint) as double) / cast(1000 as double)), None, TimestampType, Some(Etc/UTC), false) AS dateOfExperience#9641, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569]
#                                                                                  +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9507.$oid AS businessCategory#9617, createdAt#9508, dateOfExperience#9509, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9593, business_id#9569]
#                                                                                     +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9507, createdAt#9508, dateOfExperience#9509, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9523.$oid AS user#9593, business_id#9569]
#                                                                                        +- Project [__v#9503, _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9507, createdAt#9508, dateOfExperience#9509, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9523, business#9506.$oid AS business_id#9569]
#                                                                                           +- Project [__v#9503, _id#9504.$oid AS _id#9545, bookmarkedBy#9505, business#9506, businessCategory#9507, createdAt#9508, dateOfExperience#9509, downVoters#9510, downVotes#9511, experienceSummary#9512, images#9513, imagesForFlagging#9514, isEdited#9515, isFlagged#9516, isPublished#9517, rating#9518, replies#9519, upVoters#9520, upVotes#9521, updatedAt#9522, user#9523]
#                                                                                              +- Relation [__v#9503,_id#9504,bookmarkedBy#9505,business#9506,businessCategory#9507,createdAt#9508,dateOfExperience#9509,downVoters#9510,downVotes#9511,experienceSummary#9512,images#9513,imagesForFlagging#9514,isEdited#9515,isFlagged#9516,isPublished#9517,rating#9518,replies#9519,upVoters#9520,upVotes#9521,updatedAt#9522,user#9523] json
